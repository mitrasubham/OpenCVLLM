# %% [markdown]
# <a href="https://colab.research.google.com/github/mitrasubham/OpenCVLLM/blob/main/Text%20Recognition%20using%20CRNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow==2.15
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.2/475.2 MB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 56.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 53.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 74.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.0/442.0 kB 29.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.17.0
#     Uninstalling wrapt-1.17.0:
#       Successfully uninstalled wrapt-1.17.0
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.4.1
#     Uninstalling ml-dtypes-0.4.1:
#       Successfully uninstalled ml-dtypes-0.4.1
#   Attempting uninstall: keras
#     Found existing installation: keras 3.5.0
#     Uninstalling keras-3.5.0:
#       Successfully uninstalled keras-3.5.0
# ...

# %%
# !pip install keras-ocr > /dev/null

# %%
import keras_ocr
import cv2
import glob
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image = keras_ocr.tools.read("singleline.png")

# %%
pipeline = keras_ocr.pipeline.Pipeline()
# Out:
# Looking for /root/.keras-ocr/craft_mlt_25k.h5
# ...
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1260: resize_bilinear (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.image.resize(...method=ResizeMethod.BILINEAR...)` instead.
# Looking for /root/.keras-ocr/crnn_kurapan.h5
# ...

# %%
prediction_groups = pipeline.recognize([image])
# Out:
# ...
# 1/1 [==============================] - 4s 4s/step

# %%
print(prediction_groups)
# Out:
# [[('7018100', array([[ 6.,  2.],
#        [57.,  2.],
#        [57., 13.],
#        [ 6., 13.]], dtype=float32)), ('sourabh', array([[ 67.,   3.],
#        [118.,   3.],
#        [118.,  14.],
#        [ 67.,  14.]], dtype=float32)), ('vishakh', array([[128.,   3.],
#        [179.,   3.],
#        [179.,  14.],
#        [128.,  14.]], dtype=float32)), ('08', array([[190.,   3.],
#        [207.,   3.],
#        [207.,  13.],
#        [190.,  13.]], dtype=float32)), ('fo2119', array([[205.,   3.],
#        [248.,   3.],
#        [248.,  13.],
#        [205.,  13.]], dtype=float32)), ('chi', array([[253.,   3.],
#        [274.,   3.],
#        [274.,  14.],
#        [253.,  14.]], dtype=float32)), ('nchwa', array([[274.,   3.],
#        [310.,   3.],
#        [310.,  14.],
#        [274.,  14.]], dtype=float32)), ('mumbai', array([[314.,   3.],
#        [358.,   3.],
#        [358.,  14.],
#        [314.,  14.]], dtype=float32)), ('maharash', array([[377.,   3.],
#        [435.,   3.],
# ...

# %%
predictions = prediction_groups[0]

# %%
print(predictions[0])
# Out:
# ('7014100', array([[ 6.0497303,  1.8616217],
#        [57.184868 ,  3.0508118],
#        [56.918922 , 14.486486 ],
#        [ 5.783785 , 13.297297 ]], dtype=float32))

# %%
fig,ax = plt.subplots(figsize = [20,20])
keras_ocr.tools.drawAnnotations(image, predictions, ax=ax)
# Out:
# <Axes: >

# %%
recognizer = keras_ocr.recognition.Recognizer()
# Out:
# Looking for /root/.keras-ocr/crnn_kurapan.h5

# %%
image = keras_ocr.tools.read("singletext.png")

# %%
recognitions = recognizer.recognize(image)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
print(recognitions)
# Out:
# oosisha
